# %% [markdown]
# <a href="https://colab.research.google.com/github/dp457/LangChainLLM/blob/main/LangChain_LLM_Application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) Install Ollama in the Colab VM
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# 2) Start the server in the background
import subprocess, time
server = subprocess.Popen(["ollama", "serve"])
time.sleep(5)  # give it a moment to boot

# %%
# 3) Pull a smallish model
# !ollama pull llama3.1

# %%
# 4) Use LangChain
from langchain_ollama import ChatOllama
llm = ChatOllama(base_url="http://127.0.0.1:11434", model="llama3.1", temperature=0.3)
print(llm.invoke("Give me 3 LangChain project ideas.").content)
# Out:
# Here are three potential LangChain project ideas:
#
# **1. Conversational Summarization Tool**
#
# Create a conversational AI that can summarize long-form content, such as articles or research papers, in real-time. The tool would use LangChain to analyze the input text, identify key points and themes, and generate a concise summary. The user could interact with the model through natural language, asking follow-up questions or requesting clarification on specific points.
#
# **Example Use Case:** A researcher wants to quickly understand the main findings of a 10-page research paper. They can ask the conversational summarization tool to summarize the paper in a few sentences, and then drill down into specific sections for more information.
#
# **2. Dialogue-Driven Knowledge Graph Builder**
#
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "Italian", "text": "hi!"})

prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into Italian', additional_kwargs={}, response_metadata={}), HumanMessage(content='hi!', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into Italian', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='hi!', additional_kwargs={}, response_metadata={})]

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "llama3.1",                # any model you've pulled in Ollama
    model_provider="ollama",
    base_url="http://127.0.0.1:11434",
    temperature=0.3,
)

# %%
response = model.invoke(prompt)
print(response.content)
# Out:
# Ciao! Come posso aiutarti oggi?

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from English into Italian"),
    HumanMessage(content="hi!"),
]

model.invoke(messages)
# Out:
# AIMessage(content='Ciao! Come posso aiutarti oggi?', additional_kwargs={}, response_metadata={'model': 'llama3.1', 'created_at': '2025-08-30T10:51:52.96234901Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6380840701, 'load_duration': 100718664, 'prompt_eval_count': 24, 'prompt_eval_duration': 888422402, 'eval_count': 12, 'eval_duration': 5390194484, 'model_name': 'llama3.1'}, id='run--41a57432-3887-4172-b27b-b40d32308fe2-0', usage_metadata={'input_tokens': 24, 'output_tokens': 12, 'total_tokens': 36})
